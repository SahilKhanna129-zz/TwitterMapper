# %%
import boto3
from twython import Twython
import json
import time

# %%
#Access_Keys to be obtained from Twitter Application
#Used to make Twitter API request

TWITTER_ACCESS_TOKEN = '852055580361588736-2AGe368ZMmIGqGSnKIdp8n2mB7tBUny'
TWITTER_ACCESS_TOKEN_SECRET = 'nfMNs6hppOjeqLrbRMBbxJ0jx3rDw7Djup894JAIJUIJj'

#Consumer keys to access Twitter Application 

TWITTER_APP_KEY = 'Sk7ZBP8hH0E6IRdiqp4BC272R'
TWITTER_APP_KEY_SECRET = 'dAbsQBzFG0Q9fYT9NRNL2GHLiUYdbHRotrdCndDMTnrhFhIFHx'

SQS_QUEUE_NAME='TweetTrend'

#Authenticating Credentials 

twitterauth = Twython(app_key=TWITTER_APP_KEY,
            app_secret=TWITTER_APP_KEY_SECRET,
            oauth_token=TWITTER_ACCESS_TOKEN,
            oauth_token_secret=TWITTER_ACCESS_TOKEN_SECRET)

#Initializing SQS

sqs = boto3.resource( 'sqs', aws_access_key_id="AKIAJC6BX3DXNYLN54NQ", aws_secret_access_key="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",region_name='us-east-1')

queue = sqs.get_queue_by_name(QueueName=SQS_QUEUE_NAME)

print (queue.url)


def get_tweets(keyword):
    print ("Pulling Tweets")
    search = twitterauth.search(q=keyword,count=100)
    tweets = []
    tweets = search['statuses']
    for tweet in tweets:

        if tweet['geo'] != None:
            
            print (tweet['user']['lang'])
            if tweet['user']['lang']=='en':
                text = tweet['text'].lower().encode('ascii','ignore').decode('ascii')
                index = tweet['id']
                coordinates = tweet['geo']['coordinates']
                
                message={
                'id':index,
                'text':text,
                'coordinates':coordinates,
                'sentiment':''
                }
                
                temp=json.dumps(message)
                print (temp)
                response = queue.send_message(MessageBody=temp)




def twittmap():
    try:
        for i in range(1,20):
            get_tweets('movies')
            time.sleep(5)
            get_tweets('technology')
            time.sleep(5)
            get_tweets('sports')
            time.sleep(5)
            get_tweets('life')
            time.sleep(5)
            get_tweets('news')
            time.sleep(5)
            get_tweets('travel')
            time.sleep(5)
            get_tweets('health')
            time.sleep(5)
            get_tweets('awesome')
            time.sleep(5)
            get_tweets('energy')
            time.sleep(5)
            get_tweets('music')
            time.sleep(5)
    except Exception as e:
        print(str(e)) 
        
        #pass
        return

if __name__ == '__main__':
    while True:
        twittmap()
# Out:
# https://queue.amazonaws.com/550404164949/TweetTrend
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 914182795269828608, "text": "see our latest #batonrouge, la #job and click to apply: quality assurance tester - https://t.co/pvpkwpovdf #qa #hiring #careerarc", "coordinates": [30.4248607, -91.0548726], "sentiment": ""}
# en
# {"id": 914182524426887168, "text": "your only limit is you.\nlet the technology do the hard work. \nhouston proximity marketing https://t.co/9gypyc3xlb", "coordinates": [29.7629, -95.3832], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 914182849334530048, "text": "life update.\nsurvived my first month as gis mapping assistant for a https://t.co/ruxzqmyf7o", "coordinates": [47.6589, -117.425], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# ...
