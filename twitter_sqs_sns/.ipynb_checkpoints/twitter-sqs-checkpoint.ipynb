# %%
import boto3
from twython import Twython
import json
import time

# %%
#Access_Keys to be obtained from Twitter Application
#Used to make Twitter API request

TWITTER_ACCESS_TOKEN = '852055580361588736-vN0Fn0AjT7zCnRZ4Ljj7pQc4r06dtGd'
TWITTER_ACCESS_TOKEN_SECRET = 'JZlVDeK9PDJhlj0ndJrDGLoYD9q4JmtZBBmZsLFYEE1V7'

#Consumer keys to access Twitter Application 

TWITTER_APP_KEY = 'z5lTf3sAbJDjGnGFsRFcvv1MK'
TWITTER_APP_KEY_SECRET = 'HbXFtsDHCuFllDI2MBhxjUThK0Yv96JuPzn3lf3aHmVNpZCI0V'

SQS_QUEUE_NAME='Twittrends'

#Authenticating Credentials 

twitterauth = Twython(app_key=TWITTER_APP_KEY,
            app_secret=TWITTER_APP_KEY_SECRET,
            oauth_token=TWITTER_ACCESS_TOKEN,
            oauth_token_secret=TWITTER_ACCESS_TOKEN_SECRET)

#Initializing SQS

sqs = boto3.resource( 'sqs', aws_access_key_id="AKIAJC6BX3DXNYLN54NQ", aws_secret_access_key="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",region_name='us-east-1')

queue = sqs.get_queue_by_name(QueueName=SQS_QUEUE_NAME)

print (queue.url)


def get_tweets(keyword):
    print ("Pulling Tweets")
    search = twitterauth.search(q=keyword,count=100)
    tweets = []
    tweets = search['statuses']
    for tweet in tweets:

        if tweet['geo'] != None:
            
            print (tweet['user']['lang'])
            if tweet['user']['lang']=='en':
                text = tweet['text'].lower().encode('ascii','ignore').decode('ascii')
                index = tweet['id']
                coordinates = tweet['geo']['coordinates']
                
                message={
                'id':index,
                'text':text,
                'coordinates':coordinates,
                'sentiment':''
                }
                
                temp=json.dumps(message)
                print (temp)
                response = queue.send_message(MessageBody=temp)




def twittmap():
    try:
        for i in range(1,20):
            get_tweets('movies')
            time.sleep(5)
            get_tweets('technology')
            time.sleep(5)
            get_tweets('sports')
            time.sleep(5)
            get_tweets('life')
            time.sleep(5)
            get_tweets('news')
            time.sleep(5)
            get_tweets('travel')
            time.sleep(5)
            get_tweets('health')
            time.sleep(5)
            get_tweets('awesome')
            time.sleep(5)
            get_tweets('energy')
            time.sleep(5)
            get_tweets('music')
            time.sleep(5)
    except Exception as e:
        print(str(e)) 
        
        #pass
        return

if __name__ == '__main__':
    while True:
        twittmap()
# Out:
# https://queue.amazonaws.com/550404164949/Twittrends
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911795394618695680, "text": "my chronic travel daydream. \n.\n.\n.\n#malibu #beach #sunset #sky #surf #malibupier #nature #ocean https://t.co/cpne02fbgm", "coordinates": [34.0304, -118.779], "sentiment": ""}
# Pulling Tweets
# en
# {"id": 911795399337193478, "text": "share the power\ndiscover yourself\nworld heart day \n#at_the_heart_of_health https://t.co/yk4rizo6ms", "coordinates": [21.2355927, 81.6864475], "sentiment": ""}
# Pulling Tweets
# en
# {"id": 911795417565863938, "text": "psa: go to your church small group because you'll meet awesome https://t.co/osv21mjvqe", "coordinates": [33.94974, -83.3774], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911795501862854656, "text": "#tle #lifestyle https://t.co/2biifbotn3 #poetry #art #love #jazz #music  (theghanaianamericandoll) @ https://t.co/anwfejlfsr", "coordinates": [34.12907944, -80.87831731], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911795394618695680, "text": "my chronic travel daydream. \n.\n.\n.\n#malibu #beach #sunset #sky #surf #malibupier #nature #ocean https://t.co/cpne02fbgm", "coordinates": [34.0304, -118.779], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911795847813304323, "text": "#party #co #travel #noh8 #niece #beertime @ colorado https://t.co/yehjzsuuzb", "coordinates": [39.0, -105.5], "sentiment": ""}
# en
# {"id": 911795844898312192, "text": "my chronic travel daydream. \n.\n.\n.\n#malibu #beach #sunset #sky #surf #malibupier #nature #ocean https://t.co/lczrsdhy9l", "coordinates": [34.0304, -118.779], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911795883964018688, "text": "ryuko matoi commission, drawn at @cincycomicexpo . @ duke energy convention center https://t.co/gnnlkohjhm", "coordinates": [39.10093919, -84.51744441], "sentiment": ""}
# Pulling Tweets
# de
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911796010829017088, "text": "barstool sports? front row? vip? viva la mf stool baby! @ barstool https://t.co/bncf8xeu3c", "coordinates": [40.73073856, -73.99085999], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911796027547566080, "text": "hey friends all over the world don't forget to follow me so we can travel together and have fun https://t.co/q9kzlcs3lx", "coordinates": [34.0522, -118.243], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911796202487853056, "text": "i don't know the name of this opening band but their fun and have a lot of energy https://t.co/x0mpo1r1vv", "coordinates": [38.2349855, -122.6430985], "sentiment": ""}
# en
# {"id": 911796165259223040, "text": "fall equinox despacho ceremony! shifting energy for the planet. blessing into the fall season. https://t.co/eds203nfhe", "coordinates": [33.8165257, -116.5466451], "sentiment": ""}
# en
# {"id": 911796118261948416, "text": "amazing show! @brunomars has such energy, sex appeal and can freakin sing! i wish it didnt end https://t.co/mh6dlpdwpp", "coordinates": [40.75099, -73.99306], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911796263821172737, "text": "travel beshie  @ suvarnabhumi airport https://t.co/pbnigchmoh", "coordinates": [13.681111, 100.747222], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911796404259033089, "text": "awesome place. #beeroclock cheers  - drinking an ipa @ garden state hotel - https://t.co/5gjodm1vfy", "coordinates": [-37.8153, 144.971], "sentiment": ""}
# Pulling Tweets
# en
# {"id": 911796202487853056, "text": "i don't know the name of this opening band but their fun and have a lot of energy https://t.co/x0mpo1r1vv", "coordinates": [38.2349855, -122.6430985], "sentiment": ""}
# en
# {"id": 911796165259223040, "text": "fall equinox despacho ceremony! shifting energy for the planet. blessing into the fall season. https://t.co/eds203nfhe", "coordinates": [33.8165257, -116.5466451], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911796640012480512, "text": "third gig of the weekend! we're at the ville. these lollipop centerpieces are awesome. how many https://t.co/s2jcrasiwt", "coordinates": [21.3428999, -158.0398437], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911796673000570880, "text": "i'm so honored to have photographed this music man. #rip charles bradley. \n\n#music https://t.co/9zkur4aesq", "coordinates": [40.75683419, -73.84602157], "sentiment": ""}
# Pulling Tweets
# en
# {"id": 911796503894724610, "text": "#datenight with my sweetie #movies #richmond #newellcheatheam #regalgrandparkway22 @ regal grand https://t.co/pnijz9bcko", "coordinates": [29.6706697, -95.7499014], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911796836767289344, "text": "anchored for lunch #travel #love #nofilter #thisisqueensland #whitsundays @ south molle island https://t.co/sl6srg6ukf", "coordinates": [-20.24956944, 148.83025278], "sentiment": ""}
# en
# {"id": 911796631590154245, "text": "shimogamo shrine #japan #kyoto #shrine #sightseeing #trip #travel #holiday #vacation #nofilter https://t.co/uj0lirfthx", "coordinates": [35.0, 135.75], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911796880765476864, "text": "cosplayway: mia sutton! \nyooo pls show some love n follow lovely awesome gorgeous badass https://t.co/qu3fzv01k1", "coordinates": [44.88416, -93.32292], "sentiment": ""}
# en
# {"id": 911796785584197632, "text": "awesome experience .  #palexpress #cabincrew #bacolod #bound @ ninoy aquino https://t.co/fy6jcr6xy9", "coordinates": [14.508611, 121.019444], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911797034700509185, "text": "\"because life is network, there is no \"nature\" or \"environment\" separate and apart from humans. https://t.co/h9i1k82ym6", "coordinates": [-38.1583, 144.35], "sentiment": ""}
# Pulling Tweets
# pt
# Pulling Tweets
# en
# {"id": 911796836767289344, "text": "anchored for lunch #travel #love #nofilter #thisisqueensland #whitsundays @ south molle island https://t.co/sl6srg6ukf", "coordinates": [-20.24956944, 148.83025278], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911797075234443264, "text": "to be loved by @n8carlson is to be truly and completely known. after an awesome girls trip to https://t.co/ef5ouywufw", "coordinates": [32.4464, -99.7455], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911797245103808513, "text": " # # #travel #traveling #vacation #instatravel #instago #trip #holiday https://t.co/oxafwm9vjp", "coordinates": [19.45916284, 98.38015571], "sentiment": ""}
# en
# {"id": 911797122910928897, "text": " #temple #taipei #taiwan #taipeisaypaialone #travel #traveling #tflers https://t.co/zbazikrxrl", "coordinates": [16.77448333, 96.15069167], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911797394966278144, "text": "tucson arizona #street #blackandwhitephoto #streetperformer #music @ tucson, arizona https://t.co/5emahbz2wp", "coordinates": [32.22166667, -110.92638889], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911797245103808513, "text": " # # #travel #traveling #vacation #instatravel #instago #trip #holiday https://t.co/oxafwm9vjp", "coordinates": [19.45916284, 98.38015571], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911797972307816448, "text": "aceofspace_datboigood is always the life of the party @ the estate https://t.co/yhpmxxoqg1", "coordinates": [40.4284899, -74.4748199], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911797950237564929, "text": "good morning taipei! #taiwan #travel  @ taipei, taiwan https://t.co/sqxka3xlvx", "coordinates": [25.0333, 121.633], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911798085466046464, "text": "i don't know the name of this opening band but they are fun and have a lot of energy https://t.co/x0mpo28cn3", "coordinates": [38.2349855, -122.6430985], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911798247034728448, "text": "u.s. bombers, fighter jets counter 'reckless behavior' in show of force off north korea coast https://t.co/xswcwqihfd", "coordinates": [38.1500695, -79.0735978], "sentiment": ""}
# en
# {"id": 911798244371582977, "text": ": @mrwowjones -\nin other news ... it's not a race , it's a marathon. @ melbourne, victoria, https://t.co/bis0f4t2oe", "coordinates": [-37.8167, 144.967], "sentiment": ""}
# Pulling Tweets
# en
# {"id": 911797950237564929, "text": "good morning taipei! #taiwan #travel  @ taipei, taiwan https://t.co/sqxka3xlvx", "coordinates": [25.0333, 121.633], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911798171118002177, "text": "lindsay ell was awesome on guitar!!! @ hollywood casino amphitheatre https://t.co/ziheapyivh", "coordinates": [41.54397625, -87.77546024], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911798685046132736, "text": "#dripsauce @ life is beautiful https://t.co/4v9eujlzrv", "coordinates": [36.169941, -115.13983], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911798782420967425, "text": "#deadpool in the house!!!!! eaglemosscollections. such a awesome  deal for this guy today. @ https://t.co/joflhuydle", "coordinates": [38.91342907, -94.72390199], "sentiment": ""}
# en
# {"id": 911798766168047616, "text": "had an awesome day taking the @eyeexperience \"build your brand\" demo classes today!! and with https://t.co/okhqei2b0b", "coordinates": [34.16723524, -118.37258096], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911798957809872897, "text": "#selfie #taiwan #travel @  national palace museum https://t.co/6sl4c8ugid", "coordinates": [25.10179975, 121.5488076], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911799137762344962, "text": "#10krun #lovemysport #decathlon #dhuenikalgaye #nexttarget21km @ decathlon sports india cbd https://t.co/a2bizpubib", "coordinates": [28.66105929, 77.29750872], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911798957809872897, "text": "#selfie #taiwan #travel @  national palace museum https://t.co/6sl4c8ugid", "coordinates": [25.10179975, 121.5488076], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911799530881900544, "text": "jt who? pilgrimage had red yarn rocking the kids stage! @ pilgrimage music festival https://t.co/oem632i5ls", "coordinates": [35.9335403, -86.8618774], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911799378876289024, "text": " kijo semace (@ asm technology (m) sdn bhd in pasir gudang, johor) https://t.co/vaarz6e222", "coordinates": [1.46961462, 103.91402237], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911799606283063297, "text": "by bus\nchildren, middle and high school students, and adults. there are lots of state transport buses.", "coordinates": [43.80056, -70.18667], "sentiment": ""}
# en
# {"id": 911799457439784960, "text": "till next time las vegas #whhsh #vegas #lasvegas #travel #tlpicks #gltlove #traveldeeper https://t.co/h2ckx2riic", "coordinates": [36.12083333, -115.17222222], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911799378876289024, "text": " kijo semace (@ asm technology (m) sdn bhd in pasir gudang, johor) https://t.co/vaarz6e222", "coordinates": [1.46961462, 103.91402237], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911799914816049152, "text": "#travel #traveltheworld #travelphotography #wildlifephotography #elephant #thailand https://t.co/hnuugbcunv", "coordinates": [18.78156779, 99.00269588], "sentiment": ""}
# en
# {"id": 911799606283063297, "text": "by bus\nchildren, middle and high school students, and adults. there are lots of state transport buses.", "coordinates": [43.80056, -70.18667], "sentiment": ""}
# Pulling Tweets
# en
# {"id": 911799883111202816, "text": "#prince #georgewashington ballroom braintumorfoundation  help for #braintumor and #brain #health https://t.co/lnqt1qerco", "coordinates": [40.74377, -73.98682], "sentiment": ""}
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# Pulling Tweets
# en
# {"id": 911799914816049152, "text": "#travel #traveltheworld #travelphotography #wildlifephotography #elephant #thailand https://t.co/hnuugbcunv", "coordinates": [18.78156779, 99.00269588], "sentiment": ""}
