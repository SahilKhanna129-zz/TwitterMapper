# %%
import time
import boto3
import json
from elasticsearch import Elasticsearch
import os
import multiprocessing
from multiprocessing import Pool, TimeoutError
from textblob import TextBlob

# %%
# Initializing SQS

sqs = boto3.resource( 'sqs', aws_access_key_id="AKIAJC6BX3DXNYLN54NQ", aws_secret_access_key="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",region_name='us-east-1')

SQS_QUEUE_NAME='TweetTrend'

#ElasticSearch Host URL

ES_HOST_URL = "search-project1-tweet-mapper-rmxitieus6xn6vbwevmyqucbh4.us-east-1.es.amazonaws.com"

#Connecting to the ElasticSeacrh 

es = Elasticsearch(
    hosts=[{'host': ES_HOST_URL, 'port': 443}],
    use_ssl=True,
)

#Info. Elastic Search 
print(es.info())

queue = sqs.get_queue_by_name(QueueName=SQS_QUEUE_NAME)
while True:
    for message in queue.receive_messages():
        tweet = json.loads(message.body)
        if tweet is not None :
            if 'text' in tweet and type(tweet) is dict:
                tweet['sentiment'] = TextBlob(tweet['text']).sentiment.polarity
                print (tweet)
                
                #pushing data into elastic search
                es.index(index='final-tweet-index',doc_type='twitter',id = tweet['id'],body=tweet)
                print("Received")

                message.delete()
# Out:
# {'name': 'CFGdvpF', 'cluster_name': '550404164949:project1-tweet-mapper', 'cluster_uuid': 'Ky10yc3ZSoOw3T8LE4mnQA', 'version': {'number': '5.5.2', 'build_hash': 'b2f0c09', 'build_date': '2017-08-21T22:31:55.076Z', 'build_snapshot': False, 'lucene_version': '6.6.0'}, 'tagline': 'You Know, for Search'}
# {'id': 913982370054852609, 'text': "god bless technology when the pubs tv isn't working.  @ fitzroy, victoria https://t.co/ktlz5nb8ue", 'coordinates': [-37.801, 144.979], 'sentiment': 0.0}
# Received
# {'id': 913982498069086209, 'text': 'my new ash hat pika baby &amp; his awesome new #zmove!! #ashhatpikachu #ashpikachu #pikachu https://t.co/jsazyimppx', 'coordinates': [22.66791, 83.33573], 'sentiment': 0.449810606060606}
# Received
# {'id': 913982370054852609, 'text': "god bless technology when the pubs tv isn't working.  @ fitzroy, victoria https://t.co/ktlz5nb8ue", 'coordinates': [-37.801, 144.979], 'sentiment': 0.0}
# Received
# {'id': 913982697386708992, 'text': 'happy birthday my dear brother superman_3m ! wishing you good health https://t.co/li8olymhnw', 'coordinates': [29.96764, -95.5365], 'sentiment': 0.85}
# Received
# {'id': 913983537694466048, 'text': 'chura e @ alonte sports arena https://t.co/9jbzwnrlwi', 'coordinates': [14.31388889, 121.07916667], 'sentiment': 0.0}
# Received
# {'id': 913983382647902208, 'text': 'awesome and super full day in #nola so blessed to have a bestie https://t.co/nlupfode3a', 'coordinates': [29.92888257, -90.08431818], 'sentiment': 0.561111111111111}
# Received
# {'id': 913983829093879809, 'text': "this, my friends, is the life of a coach's wife. 2 sleeping babies https://t.co/hpniclp22y", 'coordinates': [32.76288681, -97.12386788], 'sentiment': 0.0}
# Received
# {'id': 913982285031948289, 'text': '#musiclesson #music @ house of piano music academy https://t.co/ypz5xoxvji', 'coordinates': [12.97686967, 80.26057184], 'sentiment': 0.0}
# Received
# {'id': 913983944974008320, 'text': ' (@ yamaha music school in prawet, bangkok w/ @birdiesdn) https://t.co/rbfwa8u5or', 'coordinates': [13.688734, 100.64791212], 'sentiment': 0.0}
# Received
# {'id': 913984651018022912, 'text': 'segundo rol da noite. @ jack music pub https://t.co/czadmtemlr', 'coordinates': [-22.32906124, -49.06847227], 'sentiment': 0.0}
# Received
# {'id': 913984709092192261, 'text': 'garlic parmesan mcspicy + twister fries + coffee float = awesome threesome! \n.\n.\n.\n#flatlay https://t.co/u3lsvz9fv9', 'coordinates': [14.560004, 121.015234], 'sentiment': 1.0}
# Received
# {'id': 913984668411793408, 'text': '@paramore killed it tonight!! #paramore #hardtimes #fun #music #live #concert #dance #awesome https://t.co/otoxnbny3y', 'coordinates': [29.57709615, -95.64366817], 'sentiment': 0.28096590909090907}
# Received
# {'id': 913985160420265984, 'text': "we weren't gone from concert, its just inl  @ alonte sports arena https://t.co/cfexkkr6hx", 'coordinates': [14.31388889, 121.07916667], 'sentiment': 0.0}
# Received
# {'id': 913985091092725760, 'text': 'can you recommend anyone for this #job? sr. manager - admin, facilities &amp; transport - https://t.co/ikiqul9rza #clerical #gurgaon, dl', 'coordinates': [28.4594965, 77.0266383], 'sentiment': 0.0}
# Received
# {'id': 913985206125596672, 'text': '#makeupbyroa \n\n@ashleycalimbahn  @ imus institute of science and technology https://t.co/pjolfyehau', 'coordinates': [14.42638889, 120.93799722], 'sentiment': 0.0}
# Received
# {'id': 913985485877497856, 'text': 'gummanayaka #fort #trek #travel #unexplored #outdoors #travelreminiscence @ pathapalya https://t.co/re7ualcqmt', 'coordinates': [13.7622856, 77.9573182], 'sentiment': 0.0}
# Received
# {'id': 913985471285514240, 'text': 'yes i crossed the bridge for brunch! awesome catch up and brunch with the #titasofsydney @ the https://t.co/10mbhxdcix', 'coordinates': [-33.81163503, 151.20182593], 'sentiment': 1.0}
# Received
# {'id': 913985206125596672, 'text': '#makeupbyroa \n\n@ashleycalimbahn  @ imus institute of science and technology https://t.co/pjolfyehau', 'coordinates': [14.42638889, 120.93799722], 'sentiment': 0.0}
# Received
# {'id': 913985641381289984, 'text': 'awesome night, time to eat and then bedtime! @ taco bell https://t.co/ml7ulajywc', 'coordinates': [29.50254171, -95.11542586], 'sentiment': 1.0}
# Received
# {'id': 913985830322147328, 'text': 'a doctor was telling me that the eccogolf shoe models with goretex technology, though pricey, https://t.co/w5chiygicd', 'coordinates': [10.3087655, 123.8952467], 'sentiment': 0.0}
# Received
# {'id': 913985887536545792, 'text': "'cause we got that power @ alonte sports arena https://t.co/c6nlcgpgfn", 'coordinates': [14.31388889, 121.07916667], 'sentiment': 0.0}
# Received
# {'id': 913985830322147328, 'text': 'a doctor was telling me that the eccogolf shoe models with goretex technology, though pricey, https://t.co/w5chiygicd', 'coordinates': [10.3087655, 123.8952467], 'sentiment': 0.0}
# Received
# {'id': 913986205359861760, 'text': "baby hold on to me! awesome!!! father/daughter!! the money's are in the house. @whoisjessemoney https://t.co/zmjssj8m4z", 'coordinates': [33.86774491, -118.06148452], 'sentiment': 1.0}
# Received
# {'id': 913986138444062721, 'text': 'awesome bay @ sutera harbour resort https://t.co/rsao9tcxvu', 'coordinates': [5.97216828, 116.0619981], 'sentiment': 1.0}
# Received
# {'id': 913985830322147328, 'text': 'a doctor was telling me that the eccogolf shoe models with goretex technology, though pricey, https://t.co/w5chiygicd', 'coordinates': [10.3087655, 123.8952467], 'sentiment': 0.0}
# Received
# {'id': 913986335626719232, 'text': 'temccchuuuu sooo much junjun, cousin and visey family for the foodies and awesome tour! we had https://t.co/ynvnlgyocs', 'coordinates': [14.05936052, 121.32974761], 'sentiment': 0.6}
# Received
# {'id': 913986659334602752, 'text': 'this pic is very awesome  @ jamundi (valle del cauca) https://t.co/etc5xxazdx', 'coordinates': [3.26666667, -76.55], 'sentiment': 1.0}
# Received
# {'id': 913986877920702464, 'text': 'liburan dadakan\n#vacation #vacancy #travel #traveling #yogyakarta #indonesian #indonesia #asia https://t.co/bedyzikjg2', 'coordinates': [-7.75512735, 110.38860261], 'sentiment': 0.0}
# Received
# {'id': 913987028416700416, 'text': "i'm at al ikhsan sports sdn bhd in kuala terengganu, terengganu w/ @banyrbk https://t.co/ajiid3snle", 'coordinates': [5.32865559, 103.13599351], 'sentiment': 0.0}
# Received
# {'id': 913987104333541376, 'text': 'a proper holiday starts with travel ...#basel @ groningen railway station https://t.co/cfiftacz72', 'coordinates': [53.210556, 6.563889], 'sentiment': 0.0}
# Received
# {'id': 913987174420246529, 'text': 'early saturday morning grind. #gnccertified @ tao technology group https://t.co/gglmurbk61', 'coordinates': [14.58093419, 121.07912289], 'sentiment': 0.1}
# Received
# {'id': 913987272005111808, 'text': 'pre game roll up at liger land! @ fitzroy victoria bowling &amp; sports club https://t.co/kfspn9bnpx', 'coordinates': [-37.78768456, 144.98066758], 'sentiment': -0.5}
# Received
# {'id': 913987325365035008, 'text': 'sleep plays animportant role in your physical health. for example,sleep is involved in healing https://t.co/jg9bxsxetj', 'coordinates': [25.30608527, 83.0104041], 'sentiment': 0.0}
# Received
# {'id': 913987391987372032, 'text': "awesome time playing at the losers route 91 booth! if you're at the @route91harvest festival, https://t.co/gayy54gwgy", 'coordinates': [36.10255224, -115.16967594], 'sentiment': 0.375}
# Received
# {'id': 913988024488349697, 'text': 'wake me up\n.\n.\n.\n#movies #vsco #vscocam #spring #throwback #university #holiday #tgif #life https://t.co/qpuvq5elha', 'coordinates': [-34.9333, 138.6], 'sentiment': 0.0}
# Received
# {'id': 913988334380183553, 'text': 'awesome friends! + lambeau field! + a packer vs. bears game! https://t.co/l6dh6emexf', 'coordinates': [44.50105578, -88.06106112], 'sentiment': 0.25}
# Received
# {'id': 913991052637347840, 'text': 'https://t.co/vnlhe2jvta sendi as-it-happens update  september 30, 2017 news gelar nobar https://t.co/wptpt2jwno #capek ? #adaaqua?', 'coordinates': [-6.22645409, 106.88087203], 'sentiment': 0.0}
# Received
# {'id': 913991174116999170, 'text': '#african #performers #great #music \n#celebrating michelles #birthday #haciendabanquethall https://t.co/iysjz7vdvh', 'coordinates': [33.3922449, -112.1358776], 'sentiment': 0.4}
# Received
# {'id': 913991126293647360, 'text': '#whynot #entertainment bringing you #newmusic this #fall2017 #music #musicislife #boom #lit https://t.co/ummpa3velb', 'coordinates': [29.42958, -98.49052], 'sentiment': 0.0}
# Received
# {'id': 913991134421987328, 'text': '#whiskeycreek #lovemymusician @ 12 north sports bar https://t.co/waszozamwl', 'coordinates': [43.14255923, -75.21652515], 'sentiment': 0.0}
# Received
# {'id': 913991246456266752, 'text': 'it was necessary...\n#lifecoachray #lifecoach #l  #necessary #god #g #n #live @ life coach ray https://t.co/ng7dr4skoj', 'coordinates': [31.08715, -97.3477], 'sentiment': 0.04545454545454545}
# Received
# {'id': 913991231679721473, 'text': 'you go #glencoco  @caninoray awesome job! @ central la, los angeles, california https://t.co/qofpqm2qdl', 'coordinates': [34.07173214, -118.30796214], 'sentiment': 0.5}
# Received
# {'id': 913991368682307585, 'text': "it takes a lot of energy to be negative.  life ain't easy ...but https://t.co/egg6lnwpr7", 'coordinates': [34.0522, -118.243], 'sentiment': 0.06666666666666668}
# Received
# {'id': 913991313300664320, 'text': "friday's highlights: middlebury edges rutland 28-27 in ot - https://t.co/wofhcpeyyh https://t.co/gozqsts6va #essex https://t.co/wxqxoifkyq", 'coordinates': [51.88561263, 0.89745373], 'sentiment': 0.0}
# Received
# {'id': 913991482171887617, 'text': 'september 29th, 2011, the services of a special surgeon extended the life of a precious animal https://t.co/xpvyk6mefl', 'coordinates': [38.2559, -85.7011], 'sentiment': 0.4285714285714286}
# Received
# {'id': 913991347958198272, 'text': "want to work at carlson wagonlit travel? we're #hiring in #singapore! click for details: https://t.co/ctyavdrgxq #customerservice #job", 'coordinates': [1.3553794, 103.8677444], 'sentiment': 0.0}
# Received
# {'id': 913991368682307585, 'text': "it takes a lot of energy to be negative.  life ain't easy ...but https://t.co/egg6lnwpr7", 'coordinates': [34.0522, -118.243], 'sentiment': 0.06666666666666668}
# Received
# {'id': 913991670710112256, 'text': 'energy was so great tonight guys!! thank you for living in this piece! #sitdown #dance https://t.co/j4nlqwalkt', 'coordinates': [38.9537659, -77.0826095], 'sentiment': 1.0}
# Received
# {'id': 913991910091640832, 'text': 'a tu imagen y semejanza! #nature #sky #cielo #nubes #clods #landscape #travel #travelphotography https://t.co/b7kqeluxmq', 'coordinates': [25.98666667, -80.14611111], 'sentiment': 0.0}
# Received
# {'id': 913991987216420864, 'text': '  #glasgow the lost glasgow communities destroyed by a controversial motorway https://t.co/4uxottovv4', 'coordinates': [55.852472, -4.309626], 'sentiment': 0.55}
# Received
# {'id': 913992401580023808, 'text': 'omg, @nottjmiller you were awesome! thank you!!!  @ house of https://t.co/telirkxi53', 'coordinates': [33.676208, -111.965708], 'sentiment': 1.0}
# Received
# {'id': 913994628168220673, 'text': "dinner time!!! @ cj's sports grill &amp; turf club https://t.co/misoygamre", 'coordinates': [33.65396, -117.29485], 'sentiment': 0.0}
# Received
